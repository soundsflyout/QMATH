# %% [markdown]
# # Lecture 2: Linear maps

# %% [markdown]
# Last time we defined the notion of a vector space, and observed that lots of vector spaces are 'mechanically the same'. Today we define the notion of linear maps, and it will give us the language to describe what it means for things to be 'mechanically the same'.
